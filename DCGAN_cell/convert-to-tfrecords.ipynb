#  extracting: /content/cell_images_32/cell_image_ (26).png
#  extracting: /content/cell_images_32/cell_image_ (30).png
#  extracting: /content/cell_images_32/cell_image_ (44).png
#   inflating: /content/cell_images_32/cell_image_ (45).png
#  extracting: /content/cell_images_32/cell_image_ (58).png
#  extracting: /content/cell_images_32/cell_image_ (63).png
#  extracting: /content/cell_images_32/cell_image_ (66).png
#   inflating: /content/cell_images_32/cell_image_ (67).png
#  extracting: /content/cell_images_32/cell_image_ (70).png
#   inflating: /content/cell_images_32/cell_image_ (71).png
#  extracting: /content/cell_images_32/cell_image_ (84).png
#   inflating: /content/cell_images_32/cell_image_ (97).png
#  extracting: /content/cell_images_32/cell_image_ (103).png
#  extracting: /content/cell_images_32/cell_image_ (104).png
#  extracting: /content/cell_images_32/cell_image_ (113).png
#  extracting: /content/cell_images_32/cell_image_ (132).png
#  extracting: /content/cell_images_32/cell_image_ (134).png
#  extracting: /content/cell_images_32/cell_image_ (135).png
#  extracting: /content/cell_images_32/cell_image_ (144).png
#  extracting: /content/cell_images_32/cell_image_ (145).png
#  extracting: /content/cell_images_32/cell_image_ (155).png
#   inflating: /content/cell_images_32/cell_image_ (166).png
#  extracting: /content/cell_images_32/cell_image_ (196).png
#  extracting: /content/cell_images_32/cell_image_ (197).png
#  extracting: /content/cell_images_32/cell_image_ (210).png
#   inflating: /content/cell_images_32/cell_image_ (211).png
#  extracting: /content/cell_images_32/cell_image_ (225).png
#  extracting: /content/cell_images_32/cell_image_ (226).png
#  extracting: /content/cell_images_32/cell_image_ (227).png
#   inflating: /content/cell_images_32/cell_image_ (234).png
#  extracting: /content/cell_images_32/cell_image_ (235).png
#  extracting: /content/cell_images_32/cell_image_ (236).png
#  extracting: /content/cell_images_32/cell_image_ (248).png
#  extracting: /content/cell_images_32/cell_image_ (266).png
#  extracting: /content/cell_images_32/cell_image_ (270).png
#  extracting: /content/cell_images_32/cell_image_ (277).png
#  extracting: /content/cell_images_32/cell_image_ (278).png
#   inflating: /content/cell_images_32/cell_image_ (279).png
#  extracting: /content/cell_images_32/cell_image_ (280).png
#   inflating: /content/cell_images_32/cell_image_ (287).png
#  extracting: /content/cell_images_32/cell_image_ (303).png
#  extracting: /content/cell_images_32/cell_image_ (304).png
#  extracting: /content/cell_images_32/cell_image_ (305).png
#   inflating: /content/cell_images_32/cell_image_ (321).png
#  extracting: /content/cell_images_32/cell_image_ (322).png
#   inflating: /content/cell_images_32/cell_image_ (339).png
#   inflating: /content/cell_images_32/cell_image_ (347).png
#  extracting: /content/cell_images_32/cell_image_ (348).png
#   inflating: /content/cell_images_32/cell_image_ (364).png
#   inflating: /content/cell_images_32/cell_image_ (365).png
#   inflating: /content/cell_images_32/cell_image_ (372).png
#   inflating: /content/cell_images_32/cell_image_ (378).png
#   inflating: /content/cell_images_32/cell_image_ (407).png
#   inflating: /content/cell_images_32/cell_image_ (410).png
#  extracting: /content/cell_images_32/cell_image_ (411).png
#   inflating: /content/cell_images_32/cell_image_ (431).png
#   inflating: /content/cell_images_32/cell_image_ (432).png
#  extracting: /content/cell_images_32/cell_image_ (433).png
#   inflating: /content/cell_images_32/cell_image_ (440).png
#   inflating: /content/cell_images_32/cell_image_ (449).png
#   inflating: /content/cell_images_32/cell_image_ (461).png
#   inflating: /content/cell_images_32/cell_image_ (472).png
#   inflating: /content/cell_images_32/cell_image_ (473).png
#   inflating: /content/cell_images_32/cell_image_ (477).png
#   inflating: /content/cell_images_32/cell_image_ (478).png
#   inflating: /content/cell_images_32/cell_image_ (585).png
#   inflating: /content/cell_images_32/cell_image_ (595).png
#  extracting: /content/cell_images_32/cell_image_ (596).png
#   inflating: /content/cell_images_32/cell_image_ (597).png
#   inflating: /content/cell_images_32/cell_image_ (609).png
#   inflating: /content/cell_images_32/cell_image_ (626).png
#   inflating: /content/cell_images_32/cell_image_ (627).png
#   inflating: /content/cell_images_32/cell_image_ (679).png
#   inflating: /content/cell_images_32/cell_image_ (694).png
#   inflating: /content/cell_images_32/cell_image_ (695).png
#   inflating: /content/cell_images_32/cell_image_ (726).png
#   inflating: /content/cell_images_32/cell_image_ (763).png
#   inflating: /content/cell_images_32/cell_image_ (764).png
#   inflating: /content/cell_images_32/cell_image_ (805).png
#   inflating: /content/cell_images_32/cell_image_ (887).png
#   inflating: /content/cell_images_32/cell_image_ (888).png
#   inflating: /content/cell_images_32/cell_image_ (901).png
#   inflating: /content/cell_images_32/cell_image_ (902).png
#   inflating: /content/cell_images_32/cell_image_ (973).png
#   inflating: /content/cell_images_32/cell_image_ (974).png
#   inflating: /content/cell_images_32/cell_image_ (1048).png
#   inflating: /content/cell_images_32/cell_image_ (1080).png
#   inflating: /content/cell_images_32/cell_image_ (1109).png
#  extracting: /content/cell_images_32/cell_image_ (1145).png
#   inflating: /content/cell_images_32/cell_image_ (1181).png
#  extracting: /content/cell_images_32/cell_image_ (1200).png
#  extracting: /content/cell_images_32/cell_image_ (1201).png
#   inflating: /content/cell_images_32/cell_image_ (1202).png
#   inflating: /content/cell_images_32/cell_image_ (1211).png
#   inflating: /content/cell_images_32/cell_image_ (1212).png
#   inflating: /content/cell_images_32/cell_image_ (1312).png
#  extracting: /content/cell_images_32/cell_image_ (1313).png
#   inflating: /content/cell_images_32/cell_image_ (1383).png
#   inflating: /content/cell_images_32/cell_image_ (1384).png
#   inflating: /content/cell_images_32/cell_image_ (1447).png
#   inflating: /content/cell_images_32/cell_image_ (1448).png
#  extracting: /content/cell_images_32/cell_image_ (1515).png
#   inflating: /content/cell_images_32/cell_image_ (1550).png
#   inflating: /content/cell_images_32/cell_image_ (1551).png
#   inflating: /content/cell_images_32/cell_image_ (1619).png
#   inflating: /content/cell_images_32/cell_image_ (1643).png
#   inflating: /content/cell_images_32/cell_image_ (1657).png
#   inflating: /content/cell_images_32/cell_image_ (1658).png
#   inflating: /content/cell_images_32/cell_image_ (1678).png
#   inflating: /content/cell_images_32/cell_image_ (1679).png
#   inflating: /content/cell_images_32/cell_image_ (1680).png
#  extracting: /content/cell_images_32/cell_image_ (1707).png
#   inflating: /content/cell_images_32/cell_image_ (1708).png

# %%
import argparse
from pathlib import Path
import random
import sys
import json

import numpy as np
import tensorflow as tf

# Default data paths.
DEFAULT_TRAIN_INPUT_DIR = Path('/content/cell_images_32')
DEFAULT_TEST_INPUT_DIR = Path('/content/test')
DEFAULT_OUTPUT_DIR = Path('./tfrecords-output')
DEFAULT_NUM_SHARDS_TRAIN = 1
DEFAULT_NUM_SHARDS_TEST = 1

# %%
def _int64_feature(value):
    return tf.train.Feature(int64_list=tf.train.Int64List(value=value))

def _bytes_feature(value):
    return tf.train.Feature(bytes_list=tf.train.BytesList(value=value))

def _float_feature(value):
  return tf.train.Feature(float_list=tf.train.FloatList(value=value))

# %%
args = None

parser = argparse.ArgumentParser()
parser.add_argument('--train-input-dir', type=Path, dest='train_input_dir',
                    default=DEFAULT_TRAIN_INPUT_DIR,
                    help='Train input directory to convert image files.')
parser.add_argument('--test-input-dir', type=Path, dest='test_input_dir',
                    default=DEFAULT_TEST_INPUT_DIR,
                    help='Test input directory to convert image files.')
parser.add_argument('--output-dir', type=Path, dest='output_dir',
                    default=DEFAULT_OUTPUT_DIR,
                    help='Output directory to store TFRecords files.')
parser.add_argument('--num-shards-train', type=int, dest='num_shards_train',
                    default=DEFAULT_NUM_SHARDS_TRAIN,
                    help='Number of shards to divide training set '
                         'TFRecords into.')
parser.add_argument('--num-shards-test', type=int, dest='num_shards_test',
                    default=DEFAULT_NUM_SHARDS_TEST,
                    help='Number of shards to divide test set '
                         'TFRecords into.')
args = parser.parse_args('')

# %%
class TFRecordsConverter(object):
    """Class that handles converting images to TFRecords."""

    def __init__(self):

        self.train_input_path = args.train_input_dir
        self.test_input_path = args.test_input_dir
        self.output_path = args.output_dir
        self.num_shards_train = args.num_shards_train
        self.num_shards_test = args.num_shards_test
        self.output_path.mkdir(exist_ok = True)

        self.train_filenames, self.num_files_train = self.process_image(self.train_input_path)

        json_dict = {'num_train_images': self.num_files_train}
        self.dump_json(json_dict)

        # Counter for total number of images processed.
        self.counter = 0

    def process_image(self, input_path):

        # Build the lists.
        images = []
        
        im_files = sorted(input_path.glob('*.png'))
        images += im_files

        num_files = len(images)

        # Randomize the order of all the images/labels.
        shuffled_indices = list(range(num_files))
        random.shuffle(shuffled_indices)

        filenames = [images[i] for i in shuffled_indices]

        return filenames, num_files

    def dump_json(self, json_dict):
        json_file = self.output_path / 'dataset.json'

        if json_file.exists():
            with json_file.open('r') as f:
                ori_json_dict = json.load(f)
            ori_json_dict.update(json_dict)
        else:
            ori_json_dict = json_dict

        with json_file.open('w') as f:
            json.dump(ori_json_dict, f)

    def write_tfrecords_file(self, output_path, filenames, indices):
        """Writes out TFRecords file."""
        writer = tf.io.TFRecordWriter(str(output_path))
        for i in indices:
            filename = filenames[i]
            try:
                im_data = filename.read_bytes()
            except:
                print("The image file cannot be read. ")
                sys.exit()

            # Example is a data format that contains a key-value store, where
            # each key maps to a Feature message. In this case, each Example
            # contains two features. One will be a ByteList for the raw image
            # data and the other will be an Int64List containing the index of
            # the corresponding label in the labels list from the file.
            example = tf.train.Example(features=tf.train.Features(feature={
                'filename': _bytes_feature([bytes(filename.name, encoding = "utf-8")]),
                'image/encoded': _bytes_feature([im_data]),}))
            writer.write(example.SerializeToString())
            self.counter += 1
            if not self.counter % 1000:
                print('Processed {} images...'.format(self.counter))
        writer.close()

    def convert(self):
        """This function will drive the conversion to TFRecords.

        Here, we partition the data into a training and testing set, then
        divide each data set into the specified number of TFRecords shards.
        """

        print('Processing training set TFRecords...')
        if self.num_shards_train > 1:
            files_per_shard = self.num_files_train // (self.num_shards_train-1)
        else:
            files_per_shard = 0

        start = 0
        for i in range(0, self.num_shards_train-1):
            shard_path = self.output_path / f'train-{i}.tfrecords'
            # Get a subset of indices to get only a subset of images/labels for
            # the current shard file.
            file_indices = np.arange(start, start+files_per_shard, dtype=int)
            start = start + files_per_shard
            self.write_tfrecords_file(shard_path, self.train_filenames, file_indices)

        # The remaining images will go in the final shard.
        file_indices = np.arange(start, self.num_files_train, dtype=int)
        if len(file_indices) > 0:
            final_shard_path = self.output_path / f'train-{self.num_shards_train}.tfrecords'
            self.write_tfrecords_file(final_shard_path, self.train_filenames, file_indices)

        if self.num_shards_test > 1:
            files_per_shard = self.num_files_test // (self.num_shards_test-1)
        else:
            files_per_shard = 0

        '''
        start = 0
        for i in range(0, self.num_shards_test-1):
            shard_path = self.output_path / f'test-{i}.tfrecords'
            # Get a subset of indices to get only a subset of images/labels for
            # the current shard file.
            file_indices = np.arange(start, start+files_per_shard, dtype=int)
            start = start + files_per_shard
            self.write_tfrecords_file(shard_path, self.test_filenames, self.test_labellist, file_indices)

        # The remaining images will go in the final shard.
        file_indices = np.arange(start, self.num_files_test, dtype=int)
        if len(file_indices) > 0:
            final_shard_path = self.output_path / f'test-{self.num_shards_test}.tfrecords'
            self.write_tfrecords_file(final_shard_path, self.test_filenames, self.test_labellist, file_indices)
        '''

        print(f'\nProcessed {self.counter} total images...')
        print(f'Number of training examples: {self.num_files_train}')
        #print(f'Number of test examples: {self.num_files_test}')
        print(f'TFRecords files saved to {str(self.output_path)}')

# %%
converter = TFRecordsConverter()
converter.convert()
# Out:
# Processing training set TFRecords...
# Processed 1000 images...
# Processed 2000 images...
# Processed 3000 images...
# Processed 4000 images...
# Processed 5000 images...
# Processed 6000 images...
#
# Processed 6000 total images...
# Number of training examples: 6000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-1abcaafcf4c3> in <module>()
#       1 converter = TFRecordsConverter()
# ----> 2 converter.convert()
#
# <ipython-input-13-e4325bc7e758> in convert(self)
#     127         print(f'\nProcessed {self.counter} total images...')
#     128         print(f'Number of training examples: {self.num_files_train}')
# --> 129         print(f'Number of test examples: {self.num_files_test}')
#     130         print(f'TFRecords files saved to {str(self.output_path)}')
#
# AttributeError: 'TFRecordsConverter' object has no attribute 'num_files_test'

# %%
# !zip -r tfreocrds-output.zip ./tfrecords-output
# Out:
#   adding: tfrecords-output/ (stored 0%)
#   adding: tfrecords-output/dataset.json (stored 0%)
#   adding: tfrecords-output/train-1.tfrecords (deflated 17%)
